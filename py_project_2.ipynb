# %% [markdown]
# ### Цели и задачи проекта
#
# <font color='#777778'>Цели: привлечь внимание людей, которые любят старые игры, и заодно заинтересовать их «Секретами Темнолесья»; сделать обзор игровых платформ, изучить объёмы продаж игр разных жанров и региональные предпочтения игроков.
# Задачи: изучить развитие игровой индустрии с 2000 по 2013 год.</font>

# %% [markdown]
# ### Описание данных
#
# <font color='#777778'>Исторические данные, которые коллеги собрали из открытых источников. В них есть информация о продажах игр, сделанных в разных жанрах и выпущенных на разных платформах, а также пользовательские и экспертные оценки игр.</font>

# %% [markdown]
# ### Содержимое проекта
#
# <font color='#777778'>
# 1  1. Загрузка данных и знакомство с ними
# 2  2. Проверка ошибок в данных и их предобработка
# 2.1  Названия, или метки, столбцов датафрейма
# 2.2  Типы данных
# 2.3  Наличие пропусков в данных
# 2.4  Явные и неявные дубликаты в данных
# 3 3. Фильтрация данных
# 4 4. Категоризация данных
# </font>
#
# ---

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними

# %%
import pandas as pd 
df = pd.read_csv('///')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16956 entries, 0 to 16955
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16954 non-null  object
#  1   Platform         16956 non-null  object
#  2   Year of Release  16681 non-null  float64
#  3   Genre            16954 non-null  object
#  4   NA sales         16956 non-null  float64
#  5   EU sales         16956 non-null  object
#  6   JP sales         16956 non-null  object
#  7   Other sales      16956 non-null  float64
#  8   Critic Score     8242 non-null   float64
#  9   User Score       10152 non-null  object
#  10  Rating           10085 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#                        Name Platform  Year of Release         Genre  NA sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#   EU sales JP sales  Other sales  Critic Score User Score Rating
# 0    28.96     3.77         8.45          76.0          8      E
# 1     3.58     6.81         0.77           NaN        NaN    NaN
# 2    12.76     3.79         3.29          82.0        8.3      E
# 3    10.93     3.28         2.95          80.0          8      E
# 4     8.89    10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Всего в предоставленной базе данных 10 столбцов и 16 956 строк. Присутствуют пропуски в столбце Name, Year of Release, Genre,
# особенно много пропусков в столбцах User Score и Rating и еще больше в Critic Score.
# Значения в столбца Year of Release, EU sales и JP sales, судя по всему, имеют нерелевантный тип данных.
# Помимо этого, не до конца понятно, в чем исчисляется показатель Sales.

# %% [markdown]
# ---
#
# ## 2.  Проверка ошибок в данных и их предобработка
#
#
# ### 2.1. Названия, или метки, столбцов датафрейма
#
# - Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
# - Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания.

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year of Release', 'Genre', 'NA sales', 'EU sales',
#        'JP sales', 'Other sales', 'Critic Score', 'User Score', 'Rating'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
print(df.columns)
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %% [markdown]
# ### 2.2. Типы данных
#
# - Если встречаются некорректные типы данных, предположите их причины.
# - При необходимости проведите преобразование типов данных. Помните, что столбцы с числовыми данными и пропусками нельзя преобразовать к типу `int64`. Сначала вам понадобится обработать пропуски, а затем преобразовать типы данных.

# %%
#df[['user_score', 'critic_score', 'year_of_release', 'rating']] = df[['user_score', 'critic_score', 'year_of_release', 'rating']].fillna(-1)
#совмещаем коды
unique_name = df['name'].unique() 
unique_platform = df['platform'].unique() 
unique_year_of_release = df['year_of_release'].unique() 
unique_genre = df['genre'].unique() 
unique_na_sales = df['na_sales'].unique() 
unique_eu_sales = df['eu_sales'].unique() 
unique_jp_sales = df['jp_sales'].unique() 
unique_other_sales = df['other_sales'].unique() 
unique_critic_score = df['critic_score'].unique() 
unique_user_score = df['user_score'].unique() 
unique_rating = df['rating'].unique()
print("Уникальные значения в столбце 'name':", unique_name) 
print("Уникальные значения в столбце 'platform':", unique_platform) 
print("Уникальные значения в столбце 'year_of_release':", unique_year_of_release) 
print("Уникальные значения в столбце 'genre':", unique_genre) 
print("Уникальные значения в столбце 'na_sales':", unique_na_sales) 
print("Уникальные значения в столбце 'eu_sales':", unique_eu_sales) 
print("Уникальные значения в столбце 'jp_sales':", unique_jp_sales) 
print("Уникальные значения в столбце 'other_sales':", unique_other_sales) 
print("Уникальные значения")
#Видим нерелевантные значения: 'unknown' в 'eu_sales' и 'unknown' в 'jp_sales'
# Out:
# Уникальные значения в столбце 'name': ['Wii Sports' 'Super Mario Bros.' 'Mario Kart Wii' ...
#  'Woody Woodpecker in Crazy Castle 5' 'LMA Manager 2007'
#  'Haitaka no Psychedelica']
# Уникальные значения в столбце 'platform': ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' 'PS4' '3DS' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'WiiU' 'GC' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# Уникальные значения в столбце 'year_of_release': [2006. 1985. 2008. 2009. 1996. 1989. 1984. 2005. 1999. 2007. 2010. 2013.
#  2004. 1990. 1988. 2002. 2001. 2011. 1998. 2015. 2012. 2014. 1992. 1997.
#  1993. 1994. 1982. 2016. 2003. 1986. 2000.   nan 1995. 1991. 1981. 1987.
#  1980. 1983.]
# Уникальные значения в столбце 'genre': ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy' nan 'MISC'
#  'ROLE-PLAYING' 'RACING' 'ACTION' 'SHOOTER' 'FIGHTING' 'SPORTS' 'PLATFORM'
# ...

# %% [markdown]
# - В числовых столбцах могут встретиться строковые значения, например `unknown` или другие. Приводите такие столбцы к числовому типу данных, заменив строковые значения на пропуски.

# %%
for column in ['eu_sales', 'jp_sales', 'user_score', 'critic_score', 'year_of_release']:
    df[column] = pd.to_numeric(df[column], errors='coerce')
# Преобразование типа данных
df['year_of_release'] = df['year_of_release'].astype('Int64')
df['user_score'] = df['user_score'].astype('Float64')

# %% [markdown]
# ### 2.3. Наличие пропусков в данных
#
# - Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.

# %%
missing_values_count = df.isna().sum()
print("Количество пропусков в каждом столбце:")
print(missing_values_count)
relative_missing_values = missing_values_count / len(df)
print("Относительное количество пропусков в каждом столбце:")
print(relative_missing_values)
# Out:
# Количество пропусков в каждом столбце:
# name                  2
# platform              0
# year_of_release     275
# genre                 2
# na_sales              0
# eu_sales              6
# jp_sales              4
# other_sales           0
# critic_score       8714
# user_score         9268
# rating             6871
# dtype: int64
# Относительное количество пропусков в каждом столбце:
# name               0.000118
# platform           0.000000
# year_of_release    0.016218
# genre              0.000118
# na_sales           0.000000
# eu_sales           0.000354
# jp_sales           0.000236
# other_sales        0.000000
# critic_score       0.513918
# user_score         0.546591
# rating             0.405225
# dtype: float64

# %% [markdown]
# - Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.

# %%
# 'name', 'year_of_release', 'genre', 'eu_sales', 'jp_sales' - drop ; 'critic_score', 'user_score'

# %% [markdown]
# В большинстве столбцов пропуски составляют не более двух процентов, что можно обозначить как незначительная часть данных.
# В столбцах 'critic_score', 'user_score' и 'rating' процент пропущенных значений уже преобретает значительный характер.
# В троках 'critic_score', 'user_score' и 'rating' пропуски могут быть обсуловленны тем, что временной промежуток, в котором
# представленны игры, является очень большим - практически вся история игропрома, и в разное время в разных регионах игры могли
# оцениваться разными системы измерения или не оцениваться вовсе. В данных столбках как заменять значения на среднее
# или другое значение, так и удалять их вовсе было бы несправедливо, поэтому их целесообразно было бы заменить
# значением индикатором (-1).
# В остальных же столбцах, в силу того, что пропуски составляют незначительную часть, их можно просто удалить.

# %% [markdown]
# - Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.
# - Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.
# - Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %%
# Общее количество строк до удаления
initial_rows = len(df)

# %%
# Удаление строк и преобрахование пропусков
df = df.dropna(subset=['name', 'year_of_release', 'genre', 'eu_sales', 'jp_sales'])
df[['user_score', 'critic_score']] = df[['user_score', 'critic_score']].fillna(-1)

# %% [markdown]
# ### 2.4. Явные и неявные дубликаты в данных
#
# - Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
# - При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.

# %%
#'genre', 'platform', 'rating'

# %%
df['genre'] = df['genre'].str.upper()
df['platform'] = df['platform'].str.upper()
df['rating'] = df['rating'].str.upper()

# %% [markdown]
# - После того как нормализуете данные и устраните неявные дубликаты, проверьте наличие явных дубликатов в данных.

# %%
# Проверка наличия дубликатов
duplicates = df[df.duplicated()]
print("Дубликаты:")
print(duplicates)


# Удаление дубликатов
#df_unique = df.drop_duplicates()
df = df.drop_duplicates()
print("Данные без дубликатов:")
print(df)
#Изменения: результаты очистки от дубликатов теперь сохранены в актуальную переменную
# Out:
# Дубликаты:
#                                                 name platform  \
# 268                            Batman: Arkham Asylum      PS3
# 368                 James Bond 007: Agent Under Fire      PS2
# 717                            God of War: Ascension      PS3
# 823                                Wipeout: The Game      WII
# 848                  Rayman Raving Rabbids: TV Party      WII
# ...                                              ...      ...
# 16671        Fullmetal Alchemist: Prince of the Dawn      WII
# 16753                                      Routes PE      PS2
# 16799                            Transformers: Prime      WII
# 16912  Metal Gear Solid V: The Definitive Experience     XONE
# 16940                          The Longest 5 Minutes      PSV
#
#        year_of_release      genre  na_sales  eu_sales  jp_sales  other_sales  \
# 268               2009     ACTION      2.24      1.31      0.07         0.61
# ...

# %%
# В столбцах 'genre', 'platform', 'rating' были произведены манипуляции с регистром для устранения неявных дубликатов. 
# В остальных столбцах явные дубликаты были устранены с помощью технологиц, предоставляемых библиотекой pandas

# %% [markdown]
# - В процессе подготовки данных вы могли что-либо удалять, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях.

# %%
# Общее количество строк после удаления
final_rows = len(df)

# %%
# Количество удалённых строк
deleted_rows = initial_rows - final_rows
print(f"Количество удалённых строк: {deleted_rows}")
# Добавляем подсчет в относительном виде
relative_deletion_percentage = (deleted_rows / initial_rows) * 100
print(f"Процент удалённых строк: {relative_deletion_percentage:.2f}%")
#Изменения: был добавлен подсчет в относительном виде
# Out:
# Количество удалённых строк: 522
# Процент удалённых строк: 3.08%

# %% [markdown]
# - После проведения предобработки данных напишите общий промежуточный вывод.

# %% [markdown]
# Большое количество пропусков в столбцах, связанных с рейтингами, может быть связано с тем, что некоторые игры были выпущены до
# введения общепринятых систем оценивание. Наличие пропусков в других частях базы данных, в своб очередь,
# учитывая их незначительность, могли быть связаны с различными ошибками при вводе данных.

# %% [markdown]
# ---
#
# ## 3. Фильтрация данных
#
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например `df_actual`.

# %%
filtered_df = df[(df['year_of_release'] >= 2000) & (df['year_of_release'] <= 2013)]
print(len(filtered_df))
#Изменения: данная проблема иправлена и отмечена выше
# Out:
# 12772

# %% [markdown]
# ---
#
# ## 4. Категоризация данных
#
# Проведите категоризацию данных:
# - Разделите все игры по оценкам пользователей и выделите такие категории: высокая оценка (от 8 до 10 включительно), средняя оценка (от 3 до 8, не включая правую границу интервала) и низкая оценка (от 0 до 3, не включая правую границу интервала).

# %%
filtered_df.loc[:, 'user_score_category'] = pd.cut(
    filtered_df['user_score'],
    bins=[0, 3, 8, 10],
    labels=['низкая оценка', 'средняя оценка', 'высокая оценка'],
    right=False
)
#мы сохранили новый срез данных в отдельном датафрейме, в связи с чем нас предупреждают о том, 
#что эти изменения не сохранятся в основном датафреме
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %% [markdown]
# - Разделите все игры по оценкам критиков и выделите такие категории: высокая оценка (от 80 до 100 включительно), средняя оценка (от 30 до 80, не включая правую границу интервала) и низкая оценка (от 0 до 30, не включая правую границу интервала).

# %%
filtered_df.loc[:, 'critic_score_category'] = pd.cut(
    filtered_df['critic_score'],
    bins=[0, 30, 80, 100],
    labels=['низкая оценка', 'средняя оценка', 'высокая оценка'],
    right=False
)

# %%
filtered_df.head()
# Out:
#                     name platform  year_of_release     genre  na_sales  \
# 0             Wii Sports      WII             2006    SPORTS     41.36
# 2         Mario Kart Wii      WII             2008    RACING     15.68
# 3      Wii Sports Resort      WII             2009    SPORTS     15.61
# 6  New Super Mario Bros.       DS             2006  PLATFORM     11.28
# 7               Wii Play      WII             2006      MISC     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 6      9.14      6.50         2.88          89.0         8.5      E
# 7      9.18      2.93         2.84          58.0         6.6      E
#
#   user_score_category critic_score_category
# 0      высокая оценка        средняя оценка
# ...

# %% [markdown]
# - После категоризации данных проверьте результат: сгруппируйте данные по выделенным категориям и посчитайте количество игр в каждой категории.

# %%
# Группируем данные по платформе и считаем количество игр для каждой платформы
platform_counts = filtered_df.groupby('platform')['name'].count().reset_index(name='count')
print(platform_counts)
# Out:
#    platform  count
# 0       3DS    300
# 1        DC     31
# 2        DS   2117
# 3        GB     27
# 4       GBA    810
# 5        GC    542
# 6       N64     70
# 7        PC    766
# 8        PS    274
# 9       PS2   2126
# 10      PS3   1087
# 11      PS4     16
# 12      PSP   1179
# 13      PSV    134
# 14      WII   1275
# 15     WIIU     74
# 16       WS      4
# 17     X360   1118
# 18       XB    803
# 19     XONE     19

# %% [markdown]
# - Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.

# %%
# Группируем данные по платформе и считаем количество игр для каждой платформы
platform_counts = filtered_df.groupby('platform')['name'].count().reset_index(name='count')

# Сортируем платформы по количеству игр в порядке убывания
platform_counts_sorted = platform_counts.sort_values(by='count', ascending=False)

# Выбираем топ-7 платформ
top_7_platforms = platform_counts_sorted.head(7)

print(top_7_platforms)
# Out:
#    platform  count
# 9       PS2   2126
# 2        DS   2117
# 14      WII   1275
# 12      PSP   1179
# 17     X360   1118
# 10      PS3   1087
# 4       GBA    810

# %% [markdown]
# ---
#
# ## 5. Итоговый вывод
#
# В конце напишите основной вывод и отразите, какую работу проделали. Не забудьте указать описание среза данных и новых полей, которые добавили в исходный датасет.

# %% [markdown]
# 'filtered_df' является датафреймом, представляющим собой срез данных в нужных для исследования годах.
# 'duplicates' - дубликаты, 'final_rows' - количество строк после предобработки данных,
# 'deleted_rows' - удаленные в процессе предобработки данных строки, 'platform_counts' - количество игр, выпущенных для каждой платформы,
# 'platform_counts_sorted' - количество игр, выпущенных для каждой платформы, отсортированные в порядке убывания,
# 'top_7_platforms' - топ семь платформ по количеству выпущенных игр

# %% [markdown]
# По итогу проделанной предобработки предоставленных в рамках проенкта данных была произведена корректировака нерелевантных типов
# данных, замена и удаление пропусков, замена и удаление явных и неявных дубликатов. Был создан новый датафрейм на основе среза
# данных в нужных для исследования годах. Помимо этого, был предоставлен топ семь платформ по количеству выпущеных игр.
